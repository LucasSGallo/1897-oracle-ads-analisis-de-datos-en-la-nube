# %%
import pandas as pd
data_set = pd.read_csv('db.csv', sep=';')
data_set
# Out:
#                     Nombre                  Motor   Año  Kilometraje  Cero_km  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003      44410.0    False
# 1                   Passat           Motor Diesel  1991       5712.0    False
# 2                 Crossfox        Motor Diesel V8  1990      37123.0    False
# 3                      DS5        Motor 2.4 Turbo  2019          NaN     True
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006      25757.0    False
# ..                     ...                    ...   ...          ...      ...
# 253           Phantom 2013               Motor V8  2014      27505.0    False
# 254  Cadillac Ciel concept               Motor V8  1991      29981.0    False
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002      52637.0    False
# 256       Aston Martin DB5           Motor Diesel  1996       7685.0    False
# 257                  Macan        Motor Diesel V6  1992      50188.0    False
#
# ...

# %%
data_set[['Kilometraje','Valor']].describe().round()
# Out:
#        Kilometraje     Valor
# count        197.0     258.0
# mean       58278.0   98961.0
# std        35837.0   29812.0
# min          107.0   50742.0
# 25%        27505.0   70744.0
# 50%        55083.0   97724.0
# 75%        90495.0  124633.0
# max       119945.0  149490.0

# %%
d = (2,4,6,4,5,7,8,9)
_, A, *_, B= d
_
# Out:
# [6, 4, 5, 7, 8]

# %%
f = 0,1,2,3,4,5,6,7
for i,j in zip(d,f):
  print(i,'=',j)
# Out:
# 2 = 0
# 4 = 1
# 6 = 2
# 4 = 3
# 5 = 4
# 7 = 5
# 8 = 6
# 9 = 7

# %%
zip()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-d14cc3da85ed> in <module>
# ----> 1 a, b, c , d1,f1,g,h,i,j,k= d
#       2 print(a,b,c)
#
# ValueError: not enough values to unpack (expected 10, got 8)
